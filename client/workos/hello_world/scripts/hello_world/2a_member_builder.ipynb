# %%
# %run ../base_setup.ipynb
# Out:
# Foundation: 2.09.024
# Transition: 2.09.022
# Engines   : 2.03.015
# Behavioral: 2.04.016

# %% [markdown]
# -------------------------
# ## Build the raw synthetic file

# %%
builder = SyntheticBuilder.from_env('members')

# %%
tools = builder.intent_model

# %%
builder.pm.reset_intents()
builder.pm_persist()

# %%
sample_size = 1000

# %%
df = pd.DataFrame()

# %%
# add a reference id
df['member_id'] = tools.get_number(range_value=10000000, to_value=100000000, precision=0, at_most=1, size=sample_size, column_name='member_id')
builder.add_column_description(column_name='member_id', description='A unique reference number limited to one million-1')

# %%
df['gender'] = tools.get_category(selection=['M', 'F'], weight_pattern=[5,3], size=sample_size, column_name='gender')
builder.add_column_description(column_name='gender', description="A gender catagory of Males and Females with bias of 5 to 3 of male to frmale")

# %%
state = ["California", "New York", "Louisiana", "New Jersey", "Virginia", "Colorado", "Nevada", 
         "Georgia", "Indiana", "Ohio", "Kentucky", "Maine", "Missouri", "Wisconsin"]
df['state'] = tools.get_category(selection=state, weight_pattern=[20, 30, 10, 5, 2, 5, 5, 1, 2, 2, 1, 1, 5, 1], size=sample_size, column_name='state')
builder.add_column_description(column_name='state', description="Only covering 14 states with a majority prediminace in California, New York and Louisiana")

# %%
# has phone number
df['has_phone_number'] = tools.get_category(selection=[1, 0], weight_pattern=[3,1], size=sample_size, column_name='has_phone_number')
builder.add_column_description(column_name='has_phone_number', description="If the person has a phone number on record with a weight bias of 3 to 1 they have")
builder.add_column_description(column_name='has_phone_number', description="There are no nulls by request")

# %%
# ensure only thoise with Phone numbers elect to not be called
selection = [builder.tools.select2dict(column='has_phone_number', condition='==1')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], weight_pattern=[1,9])
default = builder.tools.action2dict(method='@constant', value=0)

df['do_not_call'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='do_not_call')
builder.add_column_description(column_name='do_not_call', description="if thas a phone number, if they electyed to be called")

# %%
# communication channel preference
channels = ["SydneyCare", "RCP", "Phone", "Email", "SMS"]
df['channel_pref'] = tools.get_category(selection=channels, weight_pattern=[2,1,1,2,2], size=sample_size, column_name='channel_pref', intent_order=0)
builder.add_column_description(column_name='channel_pref', description="The channel through which the member contacted")

# %%
# ensure if the preference is do not call the channel preference is not Phone
selection = [builder.tools.select2dict(column='do_not_call', condition='==1'),
             builder.tools.select2dict(column='channel_pref', condition="'Phone'", operator='==', logic='AND')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], weight_pattern=[1,9])
default = builder.tools.action2dict(method='@constant', value=0)

df['channel_pref'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='channel_pref', intent_order=1)
builder.add_column_description(column_name='channel_pref', description="ensure that if do_not_call is true the preference isn't by phone")

# %%
# ensure if the member has no phone number the channel preference is not SMS or Phone
selection = [builder.tools.select2dict(column='has_phone_number', condition='==0')]

action = builder.tools.action2dict(method='get_category', selection=["SydneyCare", "RCP", "Email"], weight_pattern=[2,1,2])
default = builder.tools.action2dict(method='@header', header='channel_pref')

df['channel_pref'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='channel_pref', intent_order=2)
builder.add_column_description(column_name='channel_pref', description="ensure if the member has no phone number the channel preference is not SMS or Phone")

# %%
# segment
segment = ["Local Group", "National Accounts", "Medicaid", "BlueCard", "Medicare", "FEP", "Individual"]
df['segment'] = tools.get_category(selection=segment, weight_pattern=[38, 19, 18, 15, 5, 4, 2], size=sample_size, column_name='segment')
builder.add_column_description(column_name='segment', description="The heathcare segment of the member with bias weighting")

# %%
# age groups
df['age'] =  tools.get_number(range_value=18, to_value=90, weight_pattern=[1,2,6,4,3,1,0.1], size=sample_size, column_name='age', intent_order=0)
builder.add_column_description(column_name='age', description="age has a distribution that peaks around the mid 40's with a negative skew and older outliers")

# %%
# Adjust age for medicare being over 65
selection = [tools.select2dict(column='segment', condition="=='Medicare'")]


action = tools.action2dict(method='get_number', range_value=65, to_value=90, weight_pattern=[4,1,0.1])
default = tools.action2dict(method='@header', header='age')

df['age'] = tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='age', intent_order=1)
builder.add_column_description(column_name='segment', description="Age is a conditional influencer with Medicare being exclusivly over 65")

# %%
# flu_shot
df['flu_shot'] = tools.get_category(selection=[1, 0], weight_pattern=[4.5, 5.5], size=sample_size, column_name='flu_shot', intent_order=0)
builder.add_column_description(column_name='flu_shot', description="If the idividual has had a flu shot in the last year")
builder.add_column_description(column_name='flu_shot', description="Distribution based upon the figures taken from The Advisory Committee on Immunization Practices (ACIP)")

# %%
# adjust flu shot for under 49
selection = [builder.tools.select2dict(column='age', condition='<49')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], weight_pattern=[3,7])
default = builder.tools.action2dict(method='@header', header='flu_shot')

df['flu_shot'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='flu_shot', intent_order=1)

# %%
# adjust flu shot for over 75
selection = [builder.tools.select2dict(column='age', condition='>65')]

action = builder.tools.action2dict(method='get_category', selection=[1, 0], weight_pattern=[6.5, 3.5])
default = builder.tools.action2dict(method='@header', header='flu_shot')

df['flu_shot'] = builder.tools.correlate_selection(df, selection=selection, action=action, default_action=default, column_name='flu_shot', intent_order=2)

# %%
# email
df['email'] = tools.get_email(size=sample_size, column_name='email')
builder.add_column_description(column_name='email', description="A realistc scaled email address that is guaranteed unique")

# %%
# Latent_has_children
df['latent_has_children'] = tools.get_category(selection=[1, 0], weight_pattern=[4, 5], size=sample_size, column_name='latent_has_children')
builder.add_column_description(column_name='latent_has_children', description="a latent ditribution to indicate a member has children. Based on number of population with children")

# %%
# latent_has_travelled
df['latent_has_travelled'] = tools.get_category(selection=[1, 0], weight_pattern=[1,20], size=sample_size, column_name='latent_has_travelled')
builder.add_column_description(column_name='latent_has_travelled', description="a latent ditribution to indicate a member has recently travelled.")

# %%
builder.run_synthetic_pipeline(size=1000)

# %%
builder.report_column_catalog()
# Out:
# <style  type="text/css" >
#     #T_19cd094c_f654_11ea_b26a_784f439cb1c6 th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6 .row_heading, .blank {
#           display: none;;
#     }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row0_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row0_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row1_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row1_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row2_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row2_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row3_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row3_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row4_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row4_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row5_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row5_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row6_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row6_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row7_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row7_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row8_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row8_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row9_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row9_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row10_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row10_col1 {
#             text-align:  left;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row11_col0 {
#             text-align:  left;
#             font-weight:  bold;
#         }    #T_19cd094c_f654_11ea_b26a_784f439cb1c6row11_col1 {
#             text-align:  left;
#         }</style><table id="T_19cd094c_f654_11ea_b26a_784f439cb1c6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >column_name</th>        <th class="col_heading level0 col1" >description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row0_col0" class="data row0 col0" >age</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row0_col1" class="data row0 col1" >age has a distribution that peaks around the mid 40's with a negative skew and older outliers</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row1_col0" class="data row1 col0" >channel_pref</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row1_col1" class="data row1 col1" >The channel through which the member contacted, ensure that if do_not_call is true the preference isn't by phone, ensure if the member has no phone number the channel preference is not SMS or Phone</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row2_col0" class="data row2 col0" >do_not_call</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row2_col1" class="data row2 col1" >if thas a phone number, if they electyed to be called</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row3_col0" class="data row3 col0" >email</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row3_col1" class="data row3 col1" >A realistc scaled email address that is guaranteed unique</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row4_col0" class="data row4 col0" >flu_shot</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row4_col1" class="data row4 col1" >If the idividual has had a flu shot in the last year, Distribution based upon the figures taken from The Advisory Committee on Immunization Practices (ACIP)</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row5_col0" class="data row5 col0" >gender</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row5_col1" class="data row5 col1" >A gender catagory of Males and Females with bias of 5 to 3 of male to frmale</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row6_col0" class="data row6 col0" >has_phone_number</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row6_col1" class="data row6 col1" >If the person has a phone number on record with a weight bias of 3 to 1 they have, There are no nulls by request</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row7_col0" class="data row7 col0" >latent_has_children</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row7_col1" class="data row7 col1" >a latent ditribution to indicate a member has children. Based on number of population with children</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row8_col0" class="data row8 col0" >latent_has_travelled</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row8_col1" class="data row8 col1" >a latent ditribution to indicate a member has recently travelled.</td>
#             </tr>
#             <tr>
#                         <th id="T_19cd094c_f654_11ea_b26a_784f439cb1c6level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row9_col0" class="data row9 col0" >member_id</td>
#                         <td id="T_19cd094c_f654_11ea_b26a_784f439cb1c6row9_col1" class="data row9 col1" >A unique reference number limited to on

# %%
builder.report_intent()
# Out:
#                      order               intent  \
# level
# age                      0           get_number
#                          1  correlate_selection
# channel_pref             0         get_category
#                          1  correlate_selection
#                          2  correlate_selection
# do_not_call              0  correlate_selection
# email                    0            get_email
# flu_shot                 0         get_category
#                          1  correlate_selection
#                          2  correlate_selection
# gender                   0         get_category
# has_phone_number         0         get_category
# latent_has_children      0         get_category
# latent_has_travelled     0         get_category
# member_id                0           get_number
# segment                  0         get_category
# state                    0         get_category
#
#                                                                                                                                                                                                                    parameters  \
# level
# age                                                                                                                                  [range_value=18, to_value=90, weight_pattern=[1, 2, 6, 4, 3, 1, 0.1], column_name='age']
#                       [selection=[{'column': 'segment', 'condition': "=='Medicare'"}], action={'method': 'get_number', 'range_value': 65, 'to_value': 90, 'weight_pattern': [4, 1, 0.1]}, default_action={'method': '@head...
# channel_pref                                                                                           [selection=['SydneyCare', 'RCP', 'Phone', 'Email', 'SMS'], weight_pattern=[2, 1, 1, 2, 2], column_name='channel_pref']
#                       [selection=[{'column': 'do_not_call', 'condition': '==1'}, {'column': 'channel_pref', 'condition': "'Phone'", 'operator': '==', 'logic': 'AND'}], action={'method': 'get_category', 'selection': [1,...
#                       [selection=[{'column': 'has_phone_number', 'condition': '==0'}], action={'method': 'get_category', 'selection': ['SydneyCare', 'RCP', 'Email'], 'weight_pattern': [2, 1, 2]}, default_action={'metho...
# do_not_call           [selection=[{'column': 'has_phone_number', 'condition': '==1'}], action={'method': 'get_category', 'selection': [1, 0], 'weight_pattern': [1, 9]}, default_action={'method': '@constant', 'value': 0...
# email                                                                                                                                                                                                   [column_name='email']
# flu_shot                                                                                                                                                [selection=[1, 0], weight_pattern=[4.5, 5.5], column_name='flu_shot']
#                       [selection=[{'column': 'age', 'condition': '<49'}], action={'method': 'get_category', 'selection': [1, 0], 'weight_pattern': [3, 7]}, default_action={'method': '@header', 'header': 'flu_shot'}, co...
#                       [selection=[{'column': 'age', 'condition': '>65'}], action={'method': 'get_category', 'selection': [1, 0], 'weight_pattern': [6.5, 3.5]}, default_action={'method': '@header', 'header': 'flu_shot'}...
# gender                                                                                                                                                    [selection=['M', 'F'], weight_pattern=[5, 3], column_name='gender']
# has_phone_number                                                                                                                                    [selection=[1, 0], weight_pattern=[3, 1], column_name='has_phone_number']
# latent_has_children                                                                                                                              [selection=[1, 0], weight_pattern=[4, 5], column_name='latent_has_children']
# latent_has_travelled                                                                                                                           [selection=[1, 0], weight_pattern=[1, 20], column_name='latent_has_travelled']
# member_id                                                                                                                         [range_value=10000000, to_value=100000000, precision=0, at_most=1, column_name='member_id']
# segment                                            [selection=['Local Group', 'National Accounts', 'Medicaid', 'BlueCard', 'Medicare', 'FEP', 'Individual'], weight_pattern=[38, 19, 18, 15, 5, 4, 2], column_name='segment']
# state                 [selection=['California', 'New York', 'Louisiana', 'New Jersey', 'Virginia', 'Colorado', 'Nevada', 'Georgia', 'Indiana', 'Ohio', 'Kentucky', 'Maine', 'Missouri', 'Wisconsin'], weight_pattern=[20, ...
#
#                         creator
# level
# age                   doatridge
#                       doatridge
# channel_pref          doatridge
#                       doatridge
#                       doatridge
# do_not_call           doatridge
# email                 doatridge
# flu_shot              doatridge
#                       doatridge
#                       doatridge
# gender                doatridge
# has_phone_number      doatridge
# latent_has_children   doatridge
# latent_has_travelled  doatridge
# member_id             doatridge
# segment               doatridge
# state                 doatridge

# %% [markdown]
# -------------------------
# ## Transition

# %%
tr = Transition.from_env('members')

# %%
tr.pm.reset_intents()
tr.pm_persist()

# %%
df = tr.load_source_canonical()

# %%
df = tr.intent_model.auto_clean_header(df)
df = tr.intent_model.auto_transition(df)
df = tr.intent_model.to_remove(df, regex=['latent_'])

# %%
tr.canonical_report(df)
# Out:
# <style  type="text/css" >
#     #T_1a30c36a_f654_11ea_b26a_784f439cb1c6 th {
#           font-size: 120%;
#           text-align: center;
#     }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6 .row_heading, .blank {
#           display: none;;
#     }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col1 {
#             color:  #0f398a;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col4 {
#             background-color:  #fc9576;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col6 {
#             background-color:  #f0f9ed;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row1_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row1_col1 {
#             color:  #208a0f;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row1_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row1_col3 {
#             background-color:  #ffede5;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row1_col4 {
#             background-color:  #fdcdb9;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row1_col6 {
#             background-color:  #84cc83;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row2_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row2_col1 {
#             color:  #08488e;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row2_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row2_col3 {
#             background-color:  #fcb499;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row2_col4 {
#             background-color:  #fcb499;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row2_col6 {
#             background-color:  #a1cbe2;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row3_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row3_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row3_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row3_col4 {
#             background-color:  #ec382b;
#             color:  white;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row3_col6 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row4_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row4_col1 {
#             color:  #08488e;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row4_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row4_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row4_col4 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row4_col6 {
#             background-color:  #a1cbe2;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row5_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row5_col1 {
#             color:  #208a0f;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row5_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row5_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row5_col4 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row5_col6 {
#             background-color:  #a1cbe2;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row6_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row6_col1 {
#             color:  #08488e;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row6_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row6_col3 {
#             background-color:  #ffede5;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row6_col4 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row6_col6 {
#             background-color:  #a1cbe2;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row7_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row7_col1 {
#             color:  #0f398a;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row7_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row7_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row7_col4 {
#             background-color:  #ec382b;
#             color:  white;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row7_col6 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row8_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row8_col1 {
#             color:  #208a0f;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row8_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row8_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row8_col4 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row8_col6 {
#             background-color:  #a4da9e;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row9_col0 {
#             font-weight:  bold;
#             font-size:  120%;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row9_col1 {
#             color:  #208a0f;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row9_col2 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row9_col3 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row9_col4 {
#             : ;
#             color:  black;
#         }    #T_1a30c36a_f654_11ea_b26a_784f439cb1c6row9_col6 {
#             background-color:  #c1e6ba;
#             color:  black;
#         }</style><table id="T_1a30c36a_f654_11ea_b26a_784f439cb1c6" ><caption>%_Dom: The % most dominant element</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Attributes (10)</th>        <th class="col_heading level0 col1" >dType</th>        <th class="col_heading level0 col2" >%_Null</th>        <th class="col_heading level0 col3" >%_Dom</th>        <th class="col_heading level0 col5" >Count</th>        <th class="col_heading level0 col6" >Unique</th>        <th class="col_heading level0 col7" >Observations</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a30c36a_f654_11ea_b26a_784f439cb1c6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col0" class="data row0 col0" >age</td>
#                         <td id="T_1a30c36a_f654_11ea_b26a_784f439cb1c6row0_col1" class="data row0 col1" >int64</td>
#                         <td id="T_

# %%
tr.run_transition_pipeline()
